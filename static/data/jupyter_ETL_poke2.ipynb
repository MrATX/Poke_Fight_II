# %%
import pandas as pd
import pymongo
### Pokedex ---------------------------
# Read & Clean Data
pokemon = pd.read_csv("Pokemon.csv")
pokemon["img_url"] = "hold"
pokemon["gen_index"] = "hold"
totalpoke = pokemon.index.nunique()
for i in range(0,totalpoke):
    pokemon.iloc[i,14] = f"https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/{pokemon.iloc[i,0].item()}.png"
pokemon = pokemon.drop(columns=["Type 2"])
# Create Variables
gen_list = pokemon.loc[:,"Generation"].unique()
pokedex_fields = ["num","name","type1","total","hp","attack","defense","spatk","spdef","speed","generation","img_url","gen_index"]
pokedex_dict = {}
#wip_dict_gen = {}
wip_list_gen = []
wip_dict_poke = {}
# Master Pokemon df
pokemon_master = pokemon
pokemon_master = pokemon_master.drop(columns=["Legendary","Mega"])
# Subset Legendary Pokemon
legends = pokemon.loc[(pokemon["Legendary"]=="Yes")&(pokemon["Mega"]=="No")].reset_index()
legends = legends.drop(columns=["Legendary","Mega"])
legends = legends.iloc[:,1:]
# Filter Pokemon >500 Total Power, Non-Legendary, Non-Mega
pokemon = pokemon.loc[(pokemon["Total"]>=500)&(pokemon["Legendary"] =="No")&(pokemon["Mega"]=="No")].reset_index()
pokemon = pokemon.drop(columns=["Legendary","Mega"])
pokemon = pokemon.iloc[:,1:]
# Master Pokedex dict
for i in range(len(pokemon_master)):
    for j in range(len(pokedex_fields)):
        if type(pokemon_master.iloc[i,j])==str:
            wip_dict_poke[pokedex_fields[j]]=(pokemon_master.iloc[i,j])
        else:
            wip_dict_poke[pokedex_fields[j]]=(pokemon_master.iloc[i,j].item())
    wip_list_gen.append(wip_dict_poke)
    wip_dict_poke = {}
pokedex_dict["master"] = (wip_list_gen)
wip_list_gen = []
# Populate Pokedex dict of dicts with all filtered Pokemon, sorted into generations
for i in gen_list:
    wip_df = pokemon.loc[pokemon["Generation"]==i,:]
    index_wip = -1
    for z in range(0,wip_df.index.nunique()):
        index_wip = index_wip + 1
        wip_df.iloc[z,12] = str(index_wip)
        for j in range(len(wip_df)):
            for k in range(len(pokedex_fields)):
                if type(wip_df.iloc[j,k])==str:
                    wip_dict_poke[pokedex_fields[k]]=(wip_df.iloc[j,k])
                else:
                    wip_dict_poke[pokedex_fields[k]]=(wip_df.iloc[j,k].item())
            wip_list_gen.append(wip_dict_poke)
            wip_dict_poke = {}
        pokedex_dict[f"gen{i}"]=(wip_list_gen)
        wip_list_gen = []
# Add Legendary Pokemon dict to Pokedex
for i in range(len(legends)):
    index_wip = -1
    for z in range(0,legends.index.nunique()):
        index_wip = index_wip + 1
        legends.iloc[z,12] = str(index_wip)
        for j in range(len(pokedex_fields)):
            if type(legends.iloc[i,j])==str:
                wip_dict_poke[pokedex_fields[j]]=(legends.iloc[i,j])
            else:
                wip_dict_poke[pokedex_fields[j]]=(legends.iloc[i,j].item())
    wip_list_gen.append(wip_dict_poke)
    wip_dict_poke = {}
pokedex_dict["genL"] = (wip_list_gen)
wip_list_gen = []
# Add dict with Pokemon names for each gen
gen_name_lists = {}
wip_list = []
for i in gen_list:
    gen_name = f"gen{i}_names"
    gen = f"gen{str(i)}"
    for j in pokedex_dict[gen]:
        wip_list.append(j)
    gen_name_lists[gen_name] = (wip_list)
    wip_list = []
for i in pokedex_dict["genL"]:
    wip_list.append(i)
gen_name_lists["genL"] = (wip_list)
pokedex_dict["gen_name_lists"] = (gen_name_lists)
wip_list = []
### Combat Vars ---------------------------------
# Read Data
type_matchups = pd.read_csv("type_matchups.csv").set_index("TYPE")
# Create Variables
type_coeffs = {}
wip_dict_type = {}
types = []
for i in type_matchups:
    if i != "TYPE":
        types.append(i)
# Populate type_coeffs dict and push to combat vars
for i in range(len(types)):
    for j in range(len(types)):
        if type(type_matchups.loc[types[i],types[j]])==str:
            wip_dict_type[types[j]]=(type_matchups.loc[types[i],types[j]])
        else:
            wip_dict_type[types[j]]=(type_matchups.loc[types[i],types[j]].item())
    type_coeffs[types[i]]=(wip_dict_type)
    wip_dict_type = {}
combat_vars_dict = {}
combat_vars_dict["type_matchups"]=(type_coeffs)
# MongoDB stuffs ----------------------------------------
# Establish DB Connection (Local for meow)
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)
# Define DB
db = client.pokefight2
# Clear and Populate Collections
# Pokedex
pokedex = db.pokedex
pokedex.drop()
pokedex.insert_one(pokedex_dict)
# Combat Variables
combat_vars = db.combat_vars
combat_vars.drop()
combat_vars.insert_one(combat_vars_dict)
# Rosters for Current Match
#rosters = db.rosters
#rosters.drop()
#rosters.insert_one(rosters_dict)
# Active Pokemon in Combat
#active = db.active
#active.drop()
#active.insert_one(active_dict)

# %%
import pandas as pd
import pymongo
### Pokedex ---------------------------
# Read & Clean Data
pokemon = pd.read_csv("Pokemon.csv")
pokemon = pokemon.loc[pokemon["Mega"]=="No"].reset_index()
pokemon = pokemon.iloc[:,1:]
pokemon["img_url"] = "hold"
pokemon["gen_index"] = "hold"
totalpoke = pokemon.index.nunique()
pokemon = pokemon.fillna("(none)")
for i in range(0,totalpoke):
    pokemon.iloc[i,14] = f"https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/{pokemon.iloc[i,0].item()}.png"
# Create Variables
gen_list = pokemon.loc[:,"Generation"].unique()
pokedex_fields = ["num","name","type1","type2","total","hp","attack","defense","spatk","spdef","speed","generation","img_url","gen_index"]
pokedex_dict = {}
wip_list_gen = []
wip_dict_poke = {}
# Master Pokemon df
pokemon_master = pokemon
pokemon_master = pokemon_master.drop(columns=["Legendary","Mega"])
# Subset Legendary Pokemon
legends = pokemon.loc[(pokemon["Legendary"]=="Yes")&(pokemon["Mega"]=="No")].reset_index()
legends = legends.drop(columns=["Legendary","Mega"])
legends = legends.iloc[:,1:]
# Filter Pokemon >500 Total Power, Non-Legendary, Non-Mega
pokemon = pokemon.loc[(pokemon["Total"]>=500)&(pokemon["Legendary"] =="No")&(pokemon["Mega"]=="No")].reset_index()
pokemon = pokemon.drop(columns=["Legendary","Mega"])
pokemon = pokemon.iloc[:,1:]

# %%
import pandas as pd
import pymongo
### Pokedex ---------------------------
# Read & Clean Data
pokemon = pd.read_csv("Pokemon.csv")
pokemon = pokemon.loc[pokemon["Mega"]=="No"].reset_index()
pokemon = pokemon.iloc[:,1:]
pokemon["img_url"] = "hold"
pokemon["gen_index"] = "hold"
totalpoke = pokemon.index.nunique()
pokemon = pokemon.fillna("(none)")
for i in range(0,totalpoke):
    pokemon.iloc[i,14] = f"https://raw.githubusercontent.com/PokeAPI/sprites/master/sprites/pokemon/{pokemon.iloc[i,0].item()}.png"
# Create Variables
gen_list = pokemon.loc[:,"Generation"].unique()
pokedex_fields = ["num","name","type1","type2","total","hp","attack","defense","spatk","spdef","speed","generation","img_url","gen_index"]
pokedex_dict = {}
wip_list_gen = []
wip_dict_poke = {}
# Lightweight df
lightweight =  pokemon.loc[(pokemon["Total"]<=250)&(pokemon["Legendary"] =="No")&(pokemon["Mega"]=="No")].reset_index()
lightweight = lightweight.iloc[:,1:]
lightweight
# Midweight df
# Heavyweight df
# Legendary df
# Master df
# Out:
#       #        Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 0    10    Caterpie       Bug  (none)    195   45      30       35       20
# 1    11     Metapod       Bug  (none)    205   50      20       55       25
# 2    13      Weedle       Bug  Poison    195   40      35       30       20
# 3    14      Kakuna       Bug  Poison    205   45      25       50       25
# 4    41       Zubat    Poison  Flying    245   40      45       35       30
# 5   129    Magikarp     Water  (none)    200   20      10       55       15
# 6   161     Sentret    Normal  (none)    215   35      46       34       35
# 7   167    Spinarak       Bug  Poison    250   40      60       40       40
# 8   172       Pichu  Electric  (none)    205   20      40       15       35
# 9   173      Cleffa     Fairy  (none)    218   50      25       28       45
# 10  174   Igglybuff    Normal   Fairy    210   90      30       15       40
# 11  175      Togepi     Fairy  (none)    245   35      20       65       40
# 12  183      Marill     Water   Fairy    250   70      20       50       20
# 13  187      Hoppip     Grass  Flying    250   35      35       40       35
# 14  191     Sunkern     Grass  (none)    180   30      30       30       30
# 15  194      Wooper     Water  Ground    210   55      45       45       25
# 16  218      Slugma      Fire  (none)    250   40      40       40       70
# 17  220      Swinub       Ice  Ground    250   50      50       40       30
# 18  235    Smeargle    Normal  (none)    250   55      20       35       20
# 19  236     Tyrogue  Fighting  (none)    210   35      35       35       35
# 20  261   Poochyena      Dark  (none)    220   35      55       35       30
# 21  263   Zigzagoon    Normal  (none)    240   38      30       41       30
# 22  265     Wurmple       Bug  (none)    195   45      45       35       20
# 23  266     Silcoon       Bug  (none)    205   50      35       55       25
# 24  268     Cascoon       Bug  (none)    205   50      35       55       25
# 25  270       Lotad     Water   Grass    220   40      30       30       40
# 26  273      Seedot     Grass  (none)    220   40      40       50       30
# 27  280       Ralts   Psychic   Fairy    198   28      25       25       45
# 28  292    Shedinja       Bug   Ghost    236    1      90       45       30
# 29  293     Whismur    Normal  (none)    240   64      51       23       51
# 30  296    Makuhita  Fighting  (none)    237   72      60       30       20
# 31  298     Azurill    Normal   Fairy    190   50      20       40       20
# 32  349      Feebas     Water  (none)    200   20      15       20       10
# 33  396      Starly    Normal  Flying    245   40      55       30       30
# 34  399      Bidoof    Normal  (none)    250   59      45       40       35
# 35  401   Kricketot       Bug  (none)    194   37      25       41       25
# 36  412       Burmy       Bug  (none)    224   40      29       45       29
# 37  415      Combee       Bug  Flying    244   30      30       42       30
# 38  440     Happiny    Normal  (none)    220  100       5        5       15
# 39  659    Bunnelby    Normal  (none)    237   38      36       38       32
# 40  664  Scatterbug       Bug  (none)    200   38      35       40       27
# 41  665      Spewpa       Bug  (none)    213   45      22       60       27
# 42  714      Noibat    Flying  Dragon    245   40      30       35       45
#
#     Sp. Def  Speed  Generation Legendary Mega  \
# 0        20     45           1        No   No
# 1        25     30           1        No   No
# 2        20     50           1        No   No
# 3        25     35           1        No   No
# 4        40     55           1        No   No
# 5        20     80           1        No   No
# 6        45     20           2        No   No
# 7        40     30           2        No   No
# 8        35     60           2        No   No
# 9        55     15           2        No   No
# 10       20     15           2        No   No
# 11       65     20           2        No   No
# 12       50     40           2        No   No
# 13       55     50           2        No   No
# 14       30     30           2        No   No
# 15       25     15           2        No   No
# 16       40     20           2        No   No
# 17       30     50           2        No   No
# 18       45     75           2        No   No
# 19       35     35           2        No   No
# 20       30     35           3        No   No
# 21       41     60           3        No   No
# 22       30     20           3        No   No
# 23       25     15           3        No   No
# 24       25     15           3        No   No
# 25       50     30           3        No   No
# 26       30     30           3        No   No
# 27       35     40           3        No   No
# 28       30     40           3        No   No
# 29       23     28           3        No   No
# 30       30     25           3        No   No
# 31       40     20           3        No   No
# 32       55     80           3        No   No
# 33       30     60           4        No   No
# 34       40     31           4        No   No
# 35       41     25           4        No   No
# 36       45     36           4        No   No
# 37       42     70           4        No   No
# 38       65     30           4        No   No
# 39       36     57           6        No   No
# 40       25     35           6        No   No
# 41       30     29           6        No   No
# 42       40     55           6        No   No
#
#                                               img_url gen_index
# 0   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 1   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 2   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 3   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 4   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 5   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 6   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 7   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 8   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 9   https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 10  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 11  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 12  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 13  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 14  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 15  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 16  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 17  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 18  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 19  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 20  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 21  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 22  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 23  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 24  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 25  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 26  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 27  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 28  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 29  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 30  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 31  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 32  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 33  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 34  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 35  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 36  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 37  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 38  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 39  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 40  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 41  https://raw.githubusercontent.com/PokeAPI/spri...      hold
# 42  https://raw.githubusercontent.com/PokeAPI/spri...      hold
